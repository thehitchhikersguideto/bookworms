# %% [markdown]
# # EDA of Books
#
# ## Steps
#
# 1. [Importing the libraries](#1-importing-the-libraries)
# 2. [Importing the dataset](#2-importing-the-dataset)
# 3. [Data Cleaning](#3-data-cleaning)
# 4. [Exploratory Data Analysis](#4-exploratory-data-analysis)
# 5. [Feature Engineering](#5-feature-engineering)
# 6. [Saving the dataset](#6-saving-the-dataset)

# %% [markdown]
# ### 1. Importing the libraries

# %%
# %load_ext autoreload
# %autoreload 2
import os 
import pymongo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import datetime as dt
import time
from pandarallel import pandarallel

import math
from sklearn.pipeline import Pipeline


warnings.filterwarnings('ignore')

pandarallel.initialize()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %% [markdown]
# ### 2. Importing the dataset

# %%
# Setting the environment variables: 

# export MONGO_URI='' 
# export MONGO_DB='Goodreads'
# export MONGO_COLLECTION='Books'
MONGO_URI='mongodb+srv://vprohaska:Cottage53@recosystems.hyjorhd.mongodb.net/?retryWrites=true&w=majority'
MONGO_DB='Goodreads'
MONGO_COLLECTION='BookReviews'

# MONGO_URI = os.environ['MONGO_URI']
# MONGO_DB = os.environ['MONGO_DB']
# MONGO_COLLECTION = os.environ['MONGO_COLLECTION']
print( MONGO_DB, MONGO_COLLECTION)
# Out:
# Goodreads BookReviews

# %%
pipeline = [
    {
        '$set': {
            'reviews': {
                '$objectToArray': '$reviews'
            }
        }
    }, {
        '$unwind': {
            'path': '$reviews', 
            'preserveNullAndEmptyArrays': True
        }
    }, {
        '$set': {
            'ratings': {
                '$objectToArray': '$ratings'
            }
        }
    }, {
        '$unset': '_id'
    }
]

# %%
# Connect to Mongo 
client = pymongo.MongoClient(MONGO_URI)
db = client[MONGO_DB]
collection = db[MONGO_COLLECTION]

ret_raw = collection.aggregate(pipeline)
df_raw = pd.DataFrame(ret_raw)

# %% [markdown]
# ### 3. Data Cleaning

# %%
df_raw.isna().sum()

df_raw.head()
# Out:
#                  book_id                                            reviews  \
# 0  77203.The_Kite_Runner  {'k': '8947952', 'v': {'user_name': 'Linda', '...
# 1  77203.The_Kite_Runner  {'k': '1305882067', 'v': {'user_name': 'فرشاد'...
# 2  77203.The_Kite_Runner  {'k': '22703379', 'v': {'user_name': 'J.G. Kee...
# 3  77203.The_Kite_Runner  {'k': '9020638', 'v': {'user_name': 'Britta', ...
# 4  77203.The_Kite_Runner  {'k': '1338106', 'v': {'user_name': 'Chris', '...
#
#                                              ratings
# 0  [{'k': '5 star', 'v': '1,582,498'}, {'k': 'Rat...
# 1  [{'k': '5 star', 'v': '1,582,498'}, {'k': 'Rat...
# 2  [{'k': '5 star', 'v': '1,582,498'}, {'k': 'Rat...
# 3  [{'k': '5 star', 'v': '1,582,498'}, {'k': 'Rat...
# 4  [{'k': '5 star', 'v': '1,582,498'}, {'k': 'Rat...

# %%
#drop duplicates by book id 
df_ratings = df_raw.groupby('book_id').first().reset_index()

# %%
df_ratings
# Out:
#                                        book_id  \
# 0     1.Harry_Potter_and_the_Half_Blood_Prince
# 1                          10008056-journal-64
# 2                    10014677-front-row-center
# 3                                100237.Monkey
# 4                  1002427.Teddy_Bears_1_to_10
# ...                                        ...
# 4467                     996483.10_Fat_Turkeys
# 4468                    99664.The_Painted_Veil
# 4469                  9969571-ready-player-one
# 4470                  9975313-the-humming-room
# 4471                99894.The_Boys_from_Brazil
#
#                                                 reviews  \
# 0     {'k': '683662307', 'v': {'user_name': 'Jayson'...
# 1     {'k': '1321408528', 'v': {'user_name': 'Jayson...
# 2     {'k': '443433180', 'v': {'user_name': 'Trish J...
# 3     {'k': '2151417869', 'v': {'user_name': '°°°·.°...
# 4     {'k': '12529237', 'v': {'user_name': 'Shala Ho...
# ...                                                 ...
# 4467  {'k': '2275927619', 'v': {'user_name': 'Donna ...
# 4468  {'k': '2453989852', 'v': {'user_name': 'Jim Fo...
# 4469  {'k': '200552364', 'v': {'user_name': 'Kemper'...
# 4470  {'k': '193495728', 'v': {'user_name': 'Misty',...
# 4471  {'k': '4334398187', 'v': {'user_name': 'Baba',...
#
#                                                 ratings
# 0     [{'k': '5 star', 'v': '2,059,562'}, {'k': 'Rat...
# 1     [{'k': '5 star', 'v': '7,330'}, {'k': 'Ratings...
# 2     [{'k': '5 star', 'v': '25'}, {'k': 'Ratings_Co...
# 3     [{'k': '5 star', 'v': '2,366'}, {'k': 'Ratings...
# 4     [{'k': '5 star', 'v': '3'}, {'k': 'Ratings_Cou...
# ...                                                 ...
# 4467  [{'k': '5 star', 'v': '337'}, {'k': 'Ratings_C...
# 4468  [{'k': '5 star', 'v': '12,621'}, {'k': 'Rating...
# 4469  [{'k': '5 star', 'v': '537,735'}, {'k': 'Ratin...
# 4470  [{'k': '5 star', 'v': '1,574'}, {'k': 'Ratings...
# 4471  [{'k': '5 star', 'v': '12,897'}, {'k': 'Rating...
#
# [4472 rows x 3 columns]

# %%
# %%time

# lets take a look at one row 

one_item = df_raw.iloc[0]
# lets unpack  reviews

# one_item['reviews'].values()
 # dict_values(['8947952', {'user_name': 'Linda', 'user_id': '613434-linda', 'text': 'Finished this boo
# each review is a list of 3 elements:
# 1. the reviewer username
# 2. the reviewer user_id
# 3. the review text

# take the user_id and the text and put it into a dataframe


one_item
# Out:
# CPU times: user 98 µs, sys: 11 µs, total: 109 µs
# Wall time: 110 µs
# book_id                                77203.The_Kite_Runner
# reviews    {'k': '8947952', 'v': {'user_name': 'Linda', '...
# ratings    [{'k': '5 star', 'v': '1,582,498'}, {'k': 'Rat...
# Name: 0, dtype: object

# %%
dict_data = {d['k']: d['v'] for d in df_raw['ratings'].iloc[0]}

# add to original df 
df_raw['ratings'] = df_raw['ratings'].parallel_apply(lambda x: {d['k']: d['v'] for d in x})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 dict_data = {d['k']: d['v'] for d in df_raw['ratings'].iloc[0]}
#       3 # add to original df
#       4 df_raw['ratings'] = df_raw['ratings'].parallel_apply(lambda x: {d['k']: d['v'] for d in x})
#
# Cell In[162], line 1, in <dictcomp>(.0)
# ----> 1 dict_data = {d['k']: d['v'] for d in df_raw['ratings'].iloc[0]}
#       3 # add to original df
#       4 df_raw['ratings'] = df_raw['ratings'].parallel_apply(lambda x: {d['k']: d['v'] for d in x})
#
# TypeError: string indices must be integers

# %%
# Out:
# 0         {'5 star': '1,582,498', 'Ratings_Count': '2,93...
# 1         {'5 star': '1,582,498', 'Ratings_Count': '2,93...
# 2         {'5 star': '1,582,498', 'Ratings_Count': '2,93...
# 3         {'5 star': '1,582,498', 'Ratings_Count': '2,93...
# 4         {'5 star': '1,582,498', 'Ratings_Count': '2,93...
#                                 ...
# 114608    {'5 star': '11', 'Ratings_Count': '38', 'Total...
# 114609    {'5 star': '11', 'Ratings_Count': '38', 'Total...
# 114610    {'5 star': '7', 'Ratings_Count': '19', 'Total_...
# 114611    {'5 star': '1', 'Ratings_Count': '6', 'Total_R...
# 114612    {'5 star': '1', 'Ratings_Count': '2', 'Total_R...
# Name: ratings, Length: 114613, dtype: object

# %%
def generate_dataframe(df_raw):
    for ratings in df_raw['ratings']:
        dict_data = {d['k']: d['v'] for d in ratings }
        yield pd.DataFrame(dict_data, index=[0])

df_ratings = pd.concat(generate_dataframe(df_raw))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[161], line 6
#       3         dict_data = {d['k']: d['v'] for d in ratings }
#       4         yield pd.DataFrame(dict_data, index=[0])
# ----> 6 df_ratings = pd.concat(generate_dataframe(df_raw))
#
# File ~/Courses/projectReco/.venvbw/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Courses/projectReco/.venvbw/lib/python3.9/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~/Courses/projectReco/.venvbw/lib/python3.9/site-packages/pandas/core/reshape/concat.py:422, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     420     objs = [objs[k] for k in keys]
#     421 else:
# --> 422     objs = list(objs)
#     424 if len(objs) == 0:
#     425     raise ValueError("No objects to concatenate")
#
# Cell In[161], line 3, in generate_dataframe(df_raw)
#       1 def generate_dataframe(df_raw):
#       2     for ratings in df_raw['ratings']:
# ----> 3         dict_data = {d['k']: d['v'] for d in ratings }
#       4         yield pd.DataFrame(dict_data, index=[0])
#
# Cell In[161], line 3, in <dictcomp>(.0)
#       1 def generate_dataframe(df_raw):
#       2     for ratings in df_raw['ratings']:
# ----> 3         dict_data = {d['k']: d['v'] for d in ratings }
#       4         yield pd.DataFrame(dict_data, index=[0])
#
# TypeError: string indices must be integers

# %%
df_ratings.reset_index()
# Out:
#         index     5 star Ratings_Count Total_Review_Count   4 star   3 star  \
# 0           0  1,582,498     2,935,312             90,233  918,930  308,702
# 1           0  1,582,498     2,935,312             90,233  918,930  308,702
# 2           0  1,582,498     2,935,312             90,233  918,930  308,702
# 3           0  1,582,498     2,935,312             90,233  918,930  308,702
# 4           0  1,582,498     2,935,312             90,233  918,930  308,702
# ...       ...        ...           ...                ...      ...      ...
# 114608      0         11            38                  5       17        6
# 114609      0         11            38                  5       17        6
# 114610      0          7            19           1 review        7        4
# 114611      0          1             6                  0        0        4
# 114612      0          1             2                  0        0        0
#
#         2 star  1 star
# 0       79,972  45,210
# 1       79,972  45,210
# 2       79,972  45,210
# 3       79,972  45,210
# 4       79,972  45,210
# ...        ...     ...
# 114608       3       1
# 114609       3       1
# 114610       1       0
# 114611       1       0
# 114612       0       1
#
# [114613 rows x 8 columns]

# %%
def unpack_reviews(book_id, row):
    reviews = row['reviews']
    if pd.notna(reviews):
        for review in reviews.values():
            if type(review) == dict:
                yield book_id, review['user_id'], review['text']

# %%
dfs = []
for _, row in df_raw.iterrows():
    reviews_df = pd.DataFrame(unpack_reviews(row), columns=['user_id', 'text'])
    dfs.append(reviews_df)

# Concatenate the dataframes
df_reviews = pd.concat(dfs, ignore_index=True)

# %%
# how to join all three dataframes without losing any data?

# df_reviews
# df_ratings
# df_raw

# print all three

df_reviews_2 = df_reviews.join(df_raw['book_id'])
df_reviews_2
# Out:
#                       user_id  \
# 0                613434-linda
# 1                    31207039
# 2             84023-j-g-keely
# 3               616569-britta
# 4                 91373-chris
# ...                       ...
# 114456           1395652-sean
# 114457           966963-kevin
# 114458        1895489-maryann
# 114459  27453018-eric-gittins
# 114460       59071929-3l3azar
#
#                                                      text  \
# 0       Finished this book about a month ago but it's ...
# 1       In 2012, when I was Mathematics teacher at a p...
# 2       This is the sort of book White America reads t...
# 3       "For you, a thousand times over.""Children are...
# 4       \nDue to the large number of negative comments...
# ...                                                   ...
# 114456  Gives alternatives to start exploring what you...
# 114457  It was interesting, though it was less practic...
# 114458  If I was building a house from the ground, I t...
# 114459  Informative . Some content does not apply in o...
# 114460  Se trata de un recopilatorio de edificios cons...
#
#                       book_id
# 0       77203.The_Kite_Runner
# 1       77203.The_Kite_Runner
# 2       77203.The_Kite_Runner
# 3       77203.The_Kite_Runner
# 4       77203.The_Kite_Runner
# ...                       ...
# 114456          38743182-silo
# 114457          38743182-silo
# 114458          38743182-silo
# 114459          38743182-silo
# 114460          38743182-silo
#
# [114461 rows x 3 columns]

# %% [markdown]
# ### 4. Exploratory Data Analysis

# %% [markdown]
# ### 5. Feature Engineering

# %% [markdown]
# ### 6. Saving the dataset
