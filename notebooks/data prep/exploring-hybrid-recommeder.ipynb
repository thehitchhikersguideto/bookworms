# %% [markdown]
# ### Exploring Hybrid Recommender

# %% [markdown]
# * [Importing libraries & loading data](#chapter1)
# * [Prepare data for training](#chapter2)

# %% [markdown]
# In this notebook, we propose a hybrid book recommendation engine that combines collaborative filtering and content-based filtering using the LightFM algorithm. The dataset used for this experiment contains user ratings with little cross-rating, where users have rated only a few books with limited overlap in their ratings. Collaborative filtering, which relies on user ratings, and content-based filtering, which utilizes book metadata, are two popular approaches for building recommendation engines. However, in datasets with sparse data and limited cross-rating, both approaches may have limitations in providing accurate and diverse recommendations to users.
#
# To address these limitations, we hypothesize that a hybrid approach that combines collaborative filtering and content-based filtering using the LightFM algorithm can overcome the sparse data issue and provide more accurate and diverse recommendations. The LightFM algorithm is a flexible recommendation algorithm that can handle both explicit and implicit feedback, making it suitable for hybrid recommendation scenarios. In this notebook, we will describe the methodology for building and evaluating the hybrid book recommendation engine using the LightFM algorithm. We will outline the dataset used, the preprocessing steps, the feature engineering for content-based filtering, and the implementation of the LightFM model. We will then evaluate the performance of the hybrid approach using appropriate evaluation metrics and compare it with other traditional collaborative filtering and content-based filtering methods. Finally, we will discuss the results and implications of the experiment in the full project.

# %% [markdown]
# ### Importing libraries & loading data <a class="anchor" id="chapter1"></a>

# %%
import sys
import os

import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scrapbook as sb

from sklearn.preprocessing import LabelEncoder

import lightfm
from lightfm import LightFM
from lightfm.data import Dataset
from lightfm import cross_validation

# Import LightFM's evaluation metrics
from lightfm.evaluation import precision_at_k as lightfm_prec_at_k
from lightfm.evaluation import recall_at_k as lightfm_recall_at_k

# Import repo's evaluation metrics
from recommenders.evaluation.python_evaluation import precision_at_k, recall_at_k

from recommenders.utils.timer import Timer
from recommenders.models.lightfm.lightfm_utils import (
    track_model_metrics, prepare_test_df, prepare_all_predictions,
    compare_metric, similar_users, similar_items)

print("System version: {}".format(sys.version))
print("LightFM version: {}".format(lightfm.__version__))
# Out:
# System version: 3.9.9 | packaged by conda-forge | (main, Dec 20 2021, 02:41:37)
# [Clang 11.1.0 ]
# LightFM version: 1.16

# %%
books = pd.read_csv('../data/processed/processed_books.csv')
reviews = pd.read_csv('../data/processed/processed_reviews.csv')
ratings_dist = pd.read_csv('../data/processed/processed_ratings.csv')

# %% [markdown]
# Defining variables as per the recommenders library instructs to

# %%
# default number of recommendations
K = 10
# percentage of data used for testing
TEST_PERCENTAGE = 0.25
# model learning rate
LEARNING_RATE = 0.25
# no of latent factors
NO_COMPONENTS = 20
# no of epochs to fit model
NO_EPOCHS = 10000
# no of threads to fit model
NO_THREADS = 32
# regularisation for both user and item features
ITEM_ALPHA = 1e-6
USER_ALPHA = 1e-6

# seed for pseudonumber generations
SEED = 42

# %%
books
# Out:
#       Unnamed: 0                           book_id                     title  \
# 0              0             77203.The_Kite_Runner           The Kite Runner
# 1              1           929.Memoirs_of_a_Geisha       Memoirs of a Geisha
# 2              2   128029.A_Thousand_Splendid_Suns  A Thousand Splendid Suns
# 3              3              19063.The_Book_Thief            The Book Thief
# 4              4                   4214.Life_of_Pi                Life of Pi
# ...          ...                               ...                       ...
# 4982        6257    25489259-death-of-an-alchemist     Death of an Alchemist
# 4983        6259  52185047-the-lost-boys-of-london   The Lost Boys of London
# 4984        6262     36445482-no-cure-for-the-dead      No Cure for the Dead
# 4985        6263       15793166-the-midwife-s-tale        The Midwife's Tale
# 4986        6264        17934417-the-harlot-s-tale         The Harlot's Tale
#
#                author      price  \
# 0     Khaled Hosseini   8.717848
# 1       Arthur Golden  12.990000
# 2     Khaled Hosseini  12.990000
# 3        Markus Zusak  10.990000
# 4         Yann Martel   8.717848
# ...               ...        ...
# 4982    Mary Lawrence   5.990000
# 4983    Mary Lawrence   8.717848
# 4984  Christine Trent  12.990000
# 4985     Sam   Thomas   5.990000
# 4986     Sam   Thomas  12.990000
#
#                                                  genres  series  \
# 0     ['Fiction', 'Historical Fiction', 'Classics', ...       0
# 1     ['Fiction', 'Historical Fiction', 'Romance', '...       0
# 2     ['Fiction', 'Historical Fiction', 'Contemporar...       0
# 3     ['Historical Fiction', 'Fiction', 'Young Adult...       0
# 4     ['Fiction', 'Fantasy', 'Classics', 'Adventure'...       0
# ...                                                 ...     ...
# 4982  ['Mystery', 'Historical Fiction', 'Fiction', '...       1
# 4983  ['Mystery', 'Historical Fiction', 'Historical'...       1
# 4984  ['Mystery', 'Historical Fiction', 'Historical ...       1
# 4985  ['Historical Fiction', 'Mystery', 'Fiction', '...       1
# 4986  ['Historical Fiction', 'Mystery', 'Fiction', '...       1
#
#                publisher year_published  current_readers  wanted_to_read  \
# 0        Riverhead Books     2004-05-01          42900.0       1000000.0
# 1      Vintage Books USA     2005-11-22          12300.0        793000.0
# 2        Riverhead Books     2007-06-01          32700.0        760000.0
# 3        Alfred A. Knopf     2006-03-14          86000.0       2000000.0
# 4             Seal Books     2006-08-29          24900.0        726000.0
# ...                  ...            ...              ...             ...
# 4982    Kensington Books     2016-01-26             -1.0            -1.0
# 4983    Red Puddle Print     2020-04-28             -1.0            -1.0
# 4984  Crooked Lane Books     2018-05-08             -1.0            -1.0
# 4985      Minotaur Books     2013-01-08             -1.0            -1.0
# 4986      Minotaur Books     2014-01-07             -1.0            -1.0
#
#       num_reviews  num_ratings  rating  \
# 0              90      2935385     4.0
# 1              34      1922540     4.0
# 2              69      1417260     4.0
# 3             134      2345385     4.0
# 4              51      1544622     3.0
# ...           ...          ...     ...
# 4982           68          285     3.0
# 4983           51           99     4.0
# 4984           86          380     3.0
# 4985          421         2855     3.0
# 4986          125          859     3.0
#
#                                                  awards  \
# 0     ['Borders Original Voices Award for Fiction (2...
# 1                                                    []
# 2     ['British Book Award for Best Read of the Year...
# 3     ['National Jewish Book Award for Children’s an...
# 4     ['Booker Prize (2002)', 'Bollinger Everyman Wo...
# ...                                                 ...
# 4982                                                 []
# 4983                                                 []
# 4984                                                 []
# 4985                                                 []
# 4986                                                 []
#
#                                           primary_lists  book_score  \
# 0     ['Books That Everyone Should Read At Least Onc...    0.559392
# 1     ['Best Books Ever', 'Best Historical Fiction',...    0.504395
# 2     ['Best Books Ever', 'Books That Everyone Shoul...    0.476958
# 3     ['Best Books Ever', 'Books That Everyone Shoul...    0.527355
# 4     ['Best Books Ever', 'Books That Everyone Shoul...    0.383873
# ...                                                 ...         ...
# 4982  ['Most Anticipated Historical Mysteries for 20...    0.300015
# 4983  ['Anticipated 2020 Literary Fiction', 'Crime, ...    0.400005
# 4984  ['Historical Fiction 2018', 'Historical Myster...    0.300021
# 4985  ['Historical Fiction 2013', 'most anticipated ...    0.300155
# 4986  ['Historical Fiction 2014', 'Most Anticipated ...    0.300047
#
#       author_score
# 0         0.064747
# 1         0.052931
# 2         0.064747
# 3         0.034407
# 4         0.021261
# ...            ...
# 4982      0.000022
# 4983      0.000022
# 4984      0.000005
# 4985      0.000051
# 4986      0.000051
#
# [4987 rows x 18 columns]

# %%
# Merging to review dataset the genre characteristic by book_id
characteristics_book_df = books[['book_id', 'genres', 'price', 'publisher']]
reviews = reviews.drop('Unnamed: 0', axis = 1)
reviews = reviews[['book_id', 'user_id', 'rating']]

df = reviews.merge(characteristics_book_df, on='book_id', how='right')
df
# Out:
#                                  book_id     user_id  rating  \
# 0                  77203.The_Kite_Runner    613434.0     1.0
# 1                  77203.The_Kite_Runner  31207039.0     5.0
# 2                  77203.The_Kite_Runner     84023.0     2.0
# 3                  77203.The_Kite_Runner    616569.0     5.0
# 4                  77203.The_Kite_Runner     91373.0     1.0
# ...                                  ...         ...     ...
# 104256    25489259-death-of-an-alchemist         NaN     NaN
# 104257  52185047-the-lost-boys-of-london         NaN     NaN
# 104258     36445482-no-cure-for-the-dead         NaN     NaN
# 104259       15793166-the-midwife-s-tale         NaN     NaN
# 104260        17934417-the-harlot-s-tale         NaN     NaN
#
#                                                    genres      price  \
# 0       ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# 1       ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# 2       ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# 3       ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# 4       ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# ...                                                   ...        ...
# 104256  ['Mystery', 'Historical Fiction', 'Fiction', '...   5.990000
# 104257  ['Mystery', 'Historical Fiction', 'Historical'...   8.717848
# 104258  ['Mystery', 'Historical Fiction', 'Historical ...  12.990000
# 104259  ['Historical Fiction', 'Mystery', 'Fiction', '...   5.990000
# 104260  ['Historical Fiction', 'Mystery', 'Fiction', '...  12.990000
#
#                  publisher
# 0          Riverhead Books
# 1          Riverhead Books
# 2          Riverhead Books
# 3          Riverhead Books
# 4          Riverhead Books
# ...                    ...
# 104256    Kensington Books
# 104257    Red Puddle Print
# 104258  Crooked Lane Books
# 104259      Minotaur Books
# 104260      Minotaur Books
#
# [104261 rows x 6 columns]

# %%
df.dtypes
# Out:
# book_id       object
# user_id      float64
# rating       float64
# genres        object
# price        float64
# publisher     object
# dtype: object

# %%
df = df.dropna()
df["user_id"] = df["user_id"].astype(int)
# Out:
# /var/folders/4d/j429qptj3_s9ppcpc2sq1kwr0000gn/T/ipykernel_819/1747565825.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["user_id"] = df["user_id"].astype(int)

# %% [markdown]
# Understanding the number of users and picking the 2000 most significant ones

# %%
# Group by user_id and count ratings per user
user_ratings_count = df.groupby('user_id').size().reset_index(name='ratings_count')

# Sort by rating count in descending order
sorted_user_ratings_count = user_ratings_count.sort_values(by='ratings_count', ascending=False)

# Select the top 5000 users
top_5000_users = sorted_user_ratings_count.head(5000)
top_5000_users
# Out:
#         user_id  ratings_count
# 2814     614778            610
# 13579   4622890            246
# 26184  17438949            224
# 15097   5253785            212
# 37412  60866073            203
# ...         ...            ...
# 16086   5721271              3
# 35092  47555322              3
# 19473   7645532              3
# 16130   5743302              3
# 19465   7640495              3
#
# [5000 rows x 2 columns]

# %%
reviews_top_5000_users = pd.merge(df, top_5000_users, on='user_id', how='inner')
df = reviews_top_5000_users
df = df[['user_id', 'book_id', 'rating', 'genres', 'price', 'publisher']]

# %% [markdown]
# Encode book_id

# %%
# Instantiate a LabelEncoder object
encoder = LabelEncoder()

# Use the fit_transform method to label encode the 'Category' column
df['book_id'] = encoder.fit_transform(df['book_id'])
# Out:
# /var/folders/4d/j429qptj3_s9ppcpc2sq1kwr0000gn/T/ipykernel_819/3880552591.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['book_id'] = encoder.fit_transform(df['book_id'])

# %%
df = df.dropna(subset=['rating'])
df
# Out:
#         user_id  book_id  rating  \
# 0      31207039     3194     5.0
# 1      31207039     2232     5.0
# 2      31207039     1804     5.0
# 3      31207039     1403     4.0
# 4      31207039      104     3.0
# ...         ...      ...     ...
# 52773  49334904     2044     4.0
# 52774   2134638     1407     4.0
# 52775   2134638     2167     5.0
# 52776   2134638     2917     4.0
# 52777   2134638     2044     5.0
#
#                                                   genres      price  \
# 0      ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# 1      ['Nonfiction', 'Psychology', 'Philosophy', 'Hi...   8.717848
# 2      ['Philosophy', 'Classics', 'Nonfiction', 'Poli...  10.990000
# 3      ['Nonfiction', 'History', 'Science', 'Philosop...   8.717848
# 4      ['Classics', 'Fiction', 'Literature', 'Novels'...   8.717848
# ...                                                  ...        ...
# 52773         ['Horror', 'Anthologies', 'Short Stories']   8.717848
# 52774         ['Horror', 'Short Stories', 'Anthologies']   8.717848
# 52775         ['Horror', 'Anthologies', 'Short Stories']   8.717848
# 52776         ['Horror', 'Anthologies', 'Short Stories']   8.717848
# 52777         ['Horror', 'Anthologies', 'Short Stories']   8.717848
#
#                          publisher
# 0                  Riverhead Books
# 1                     Beacon Press
# 2                 Penguin Classics
# 3                          Vintage
# 4            Vintage International
# ...                            ...
# 52773                 Mosaic Press
# 52774  Cemetery Dance Publications
# 52775  Cemetery Dance Publications
# 52776  Cemetery Dance Publications
# 52777                 Mosaic Press
#
# [52778 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# user_id      0
# book_id      0
# rating       0
# genres       0
# price        0
# publisher    0
# dtype: int64

# %%
df.drop_duplicates(subset=['user_id', 'book_id'], inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Prepare data for training <a class="anchor" id="chapter2"></a>

# %% [markdown]
# Before fitting the LightFM model, we need to create an instance of Dataset which holds the interaction matrix.

# %%
dataset = Dataset()

# %%
dataset.fit(users=df['user_id'], 
            items=df['book_id'])

# quick check to determine the number of unique users and items in the data
num_users, num_topics = dataset.interactions_shape()
print(f'Num users: {num_users}, num_topics: {num_topics}.')
# Out:
# Num users: 5000, num_topics: 3596.

# %% [markdown]
# Next is to build the interaction matrix. The build_interactions method returns 2 COO sparse matrices, namely the interactions and weights matrices.

# %%
(interactions, weights) = dataset.build_interactions(df.iloc[:, 0:3].values)

# %%
train_interactions, test_interactions = cross_validation.random_train_test_split(
    interactions, test_percentage=TEST_PERCENTAGE,
    random_state=np.random.RandomState(SEED))

# %%
print(f"Shape of train interactions: {train_interactions.shape}")
print(f"Shape of test interactions: {test_interactions.shape}")
# Out:
# Shape of train interactions: (5000, 3596)
# Shape of test interactions: (5000, 3596)

# %% [markdown]
# #### Fitting the LightFM model

# %%
model1 = LightFM(loss='warp', no_components=20, 
                 learning_rate=LEARNING_RATE,                 
                 random_state=np.random.RandomState(SEED))

# %%
model1 = model1.fit(train_interactions, epochs=NO_EPOCHS, num_threads=NO_THREADS, verbose=False)

# %%
uids, iids, interaction_data = cross_validation._shuffle(
    interactions.row, interactions.col, interactions.data, 
    random_state=np.random.RandomState(SEED))

cutoff = int((1.0 - TEST_PERCENTAGE) * len(uids))
test_idx = slice(cutoff, None)

# %%
print(type(test_idx))
# Out:
# <class 'slice'>

# %%
uid_map, ufeature_map, iid_map, ifeature_map = dataset.mapping()

# %%
with Timer() as test_time:
    test_df = prepare_test_df(test_idx, uids, iids, uid_map, iid_map, weights)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict test data.")  
time_reco1 = test_time.interval
# Out:
# Took 1.2 seconds for prepare and predict test data.

# %%
test_df.sample(5, random_state=SEED)
# Out:
#         userID  itemID  rating
# 6170   4213258     505     4.0
# 8108  14684638    1221     5.0
# 2447  50424456    1332     4.0
# 3132  52545435    2648     4.0
# 6778  84049050    2725     4.0

# %%
df = df.rename(columns={"user_id": "userID",'book_id': 'itemID'})

# %%
# with Timer() as test_time:
#     all_predictions = prepare_all_predictions(df, uid_map, iid_map, 
#                                               interactions=train_interactions,
#                                               model=model1, 
#                                               num_threads=NO_THREADS)
# print(f"Took {test_time.interval:.1f} seconds for prepare and predict all data.")
# time_reco2 = test_time.interval

# %%
all_predictions = pd.read_csv('../data/processed/all_predictions.csv')

# %%
all_predictions.sample(5, random_state=SEED)
all_predictions.drop(columns=['Unnamed: 0', "Unnamed: 0.1"], axis = 1, inplace = True)

# %%
all_predictions
# Out:
#            userID  itemID    prediction
# 0        31207039    1804 -1.450593e+07
# 1        31207039    2115 -1.137490e+09
# 2        31207039    2559 -3.342550e+06
# 3        31207039    1981 -2.849655e+07
# 4        31207039    3542 -2.127561e+08
# ...           ...     ...           ...
# 7667008   1935255    1277  6.849396e+07
# 7667009   1935255    2980 -5.445119e+06
# 7667010   1935255    1298 -1.023283e+08
# 7667011   1935255      20  5.868065e+06
# 7667012   1935255    3232  4.138008e+09
#
# [7667013 rows x 3 columns]

# %%
with Timer() as test_time:
    eval_precision_lfm = lightfm_prec_at_k(model1, test_interactions, 
                                           train_interactions, k=K).mean()
    eval_recall_lfm = lightfm_recall_at_k(model1, test_interactions, 
                                          train_interactions, k=K).mean()
time_lfm = test_time.interval
    
print(
    "\n------ Using LightFM evaluation methods ------",
    f"Precision@K:\t{eval_precision_lfm:.6f}",
    f"Recall@K:\t{eval_recall_lfm:.6f}", 
    sep='\n')
# Out:
# ------ Using LightFM evaluation methods ------
# Precision@K:	0.008241
# Recall@K:	0.020841

# %%
df
# Out:
#          userID  itemID  rating  \
# 0      31207039    3194     5.0
# 1      31207039    2232     5.0
# 2      31207039    1804     5.0
# 3      31207039    1403     4.0
# 4      31207039     104     3.0
# ...         ...     ...     ...
# 52773  49334904    2044     4.0
# 52774   2134638    1407     4.0
# 52775   2134638    2167     5.0
# 52776   2134638    2917     4.0
# 52777   2134638    2044     5.0
#
#                                                   genres      price  \
# 0      ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# 1      ['Nonfiction', 'Psychology', 'Philosophy', 'Hi...   8.717848
# 2      ['Philosophy', 'Classics', 'Nonfiction', 'Poli...  10.990000
# 3      ['Nonfiction', 'History', 'Science', 'Philosop...   8.717848
# 4      ['Classics', 'Fiction', 'Literature', 'Novels'...   8.717848
# ...                                                  ...        ...
# 52773         ['Horror', 'Anthologies', 'Short Stories']   8.717848
# 52774         ['Horror', 'Short Stories', 'Anthologies']   8.717848
# 52775         ['Horror', 'Anthologies', 'Short Stories']   8.717848
# 52776         ['Horror', 'Anthologies', 'Short Stories']   8.717848
# 52777         ['Horror', 'Anthologies', 'Short Stories']   8.717848
#
#                          publisher
# 0                  Riverhead Books
# 1                     Beacon Press
# 2                 Penguin Classics
# 3                          Vintage
# 4            Vintage International
# ...                            ...
# 52773                 Mosaic Press
# 52774  Cemetery Dance Publications
# 52775  Cemetery Dance Publications
# 52776  Cemetery Dance Publications
# 52777                 Mosaic Press
#
# [52583 rows x 6 columns]

# %%
import ast 

def extract_genre_counts(df, column_name):
    """
    Extracts genre counts from a column of lists that are represented as strings in a pandas DataFrame.
    
    Args:
    - df (pandas.DataFrame): The DataFrame that contains the column of interest.
    - column_name (str): The name of the column of interest.
    
    Returns:
    - dict: A dictionary with the count of each genre found in the column.
    """
    # Extract the column as a Series
    column = df[column_name]
    
    # Convert the strings representing lists to actual lists
    column = column.apply(ast.literal_eval)
    
    # Count the occurrences of each genre in the column
    genre_counts = {}
    for lst in column:
        for genre in lst:
            if genre in genre_counts:
                genre_counts[genre] += 1
            else:
                genre_counts[genre] = 1
    
    return genre_counts

genre_counts = extract_genre_counts(df, 'genres')

print(genre_counts)
# Out:
# {'Fiction': 38158, 'Historical Fiction': 10858, 'Classics': 11340, 'Contemporary': 10250, 'Novels': 4027, 'Historical': 7883, 'Literature': 5296, 'Nonfiction': 5360, 'Psychology': 494, 'Philosophy': 1035, 'History': 3342, 'Self Help': 371, 'Memoir': 2117, 'Biography': 2424, 'Politics': 1648, 'School': 1441, 'Science': 761, 'Anthropology': 165, 'Audiobook': 9440, 'American': 728, '20th Century': 328, 'Southern Gothic': 62, 'Read For School': 123, 'Feminism': 929, 'Essays': 479, 'Writing': 150, 'Africa': 740, 'Spirituality': 164, 'Religion': 565, 'Buddhism': 42, 'Fantasy': 17886, 'Adventure': 5417, 'High Fantasy': 1889, 'Science Fiction Fantasy': 4026, 'Epic Fantasy': 1551, 'Mystery': 12023, 'Thriller': 8103, 'Mystery Thriller': 5880, 'Suspense': 3853, 'Adult': 5316, 'France': 626, 'Science Fiction': 7631, 'Space Opera': 1841, 'Young Adult': 10991, 'Childrens': 4727, 'Middle Grade': 3411, 'Christian': 175, 'Poetry': 1791, 'Mythology': 1712, 'American History': 568, 'Social Justice': 630, 'Theory': 69, 'Sociology': 341, 'Race': 1108, 'Anti Racist': 310, 'Dystopia': 2097, 'War': 2794, 'Space': 1212, 'Cultural': 298, 'Humor': 2885, 'Comedy': 825, 'Graphic Novels': 984, 'Comics': 972, 'Graphic Novels Comics': 472, 'Comic Book': 316, 'Economics': 210, 'Coming Of Age': 508, 'Gothic': 638, 'Horror': 2914, 'Dragons': 672, 'Magic': 2989, 'Alternate History': 201, 'Urban Fantasy': 1954, 'Sword and Sorcery': 37, 'Dark Fantasy': 212, 'Short Stories': 1845, 'Plays': 401, 'Drama': 630, 'Theatre': 265, 'Speculative Fiction': 462, 'Biography Memoir': 569, 'Autobiography': 519, 'LGBT': 3867, 'Cyberpunk': 108, 'Post Apocalyptic': 404, 'Arthurian': 87, 'Russia': 588, 'Romance': 15090, 'Japan': 348, 'World War II': 880, 'Magical Realism': 685, 'China': 1155, 'Asia': 1252, 'Travel': 643, 'British Literature': 1298, 'Holocaust': 309, 'Crime': 7424, 'Detective': 2552, 'Womens': 178, 'Literary Fiction': 3222, 'Dark': 483, 'Canada': 1495, 'Nigeria': 99, 'Realistic Fiction': 2131, 'Teen': 628, 'Christmas': 302, 'Productivity': 33, 'Personal Development': 189, 'Business': 245, 'Technology': 48, 'Adult Fiction': 1041, 'Music': 620, 'India': 415, 'Indian Literature': 194, 'Animals': 1099, 'Vampires': 974, 'Paranormal': 4531, 'Autistic Spectrum Disorder': 37, 'Inspirational': 145, 'Mental Health': 409, 'Queer': 983, 'Greek Mythology': 759, 'Retellings': 579, 'Picture Books': 1389, 'Books About Books': 385, 'True Crime': 173, 'Book Club': 629, 'Ireland': 222, 'Spain': 140, 'Education': 144, 'Iran': 59, 'Botswana': 50, 'Czech Literature': 39, 'Chick Lit': 1614, 'Journalism': 37, 'Japanese Literature': 123, 'Irish Literature': 112, 'Australia': 210, 'Historical Romance': 585, 'Pirates': 63, 'Morocco': 23, 'South Africa': 38, 'Russian Literature': 321, 'Time Travel': 868, 'Espionage': 468, 'Action': 644, 'Medieval': 366, 'Westerns': 563, 'Military Fiction': 1347, 'Noir': 156, 'Medicine': 197, 'Medical': 173, 'African American': 433, 'Steampunk': 237, 'Anthologies': 343, 'Fae': 350, 'Italian Literature': 84, 'German Literature': 183, 'Zombies': 87, 'Civil War': 178, '15th Century': 21, 'Plantagenet': 56, 'African Literature': 28, 'New Adult': 2005, 'Contemporary Romance': 2871, 'College': 475, 'Fairy Tales': 592, '19th Century': 281, 'Paranormal Romance': 1579, 'Victorian': 93, 'Angels': 249, 'Supernatural': 420, 'Nature': 339, 'Entrepreneurship': 18, 'Finance': 36, 'Political Science': 31, 'Reference': 87, 'Mental Illness': 98, 'Leadership': 67, 'Aliens': 1368, 'Art': 168, 'French Literature': 154, 'Christian Fiction': 60, 'Faith': 12, 'Spanish Literature': 68, 'Germany': 82, 'Sweden': 740, 'Roman': 21, 'Scandinavian Literature': 1361, 'Swedish Literature': 67, 'Food': 204, 'Young Adult Fantasy': 644, 'Apocalyptic': 76, 'Witches': 192, 'Werewolves': 266, 'Epic': 217, 'Gay': 1438, 'Horses': 49, 'Holiday': 315, 'Juvenile': 391, 'Christianity': 65, 'Theology': 34, 'Nordic Noir': 655, 'Nobel Prize': 139, 'Canadian Literature': 490, 'Historical Fantasy': 174, 'The Un ...

# %%
# Sort the genre counts by the count in descending order
sorted_genre_counts = sorted(genre_counts.items(), key=lambda x: x[1], reverse=True)

# Select the top 20 genres
top_20_genres = [genre for genre, count in sorted_genre_counts[:20]]

print(top_20_genres)
# Output: ['Drama', 'Horror', 'Anthologies', 'Short Stories', 'Comedy', 'Mystery', 'Thriller']
# Out:
# ['Fiction', 'Fantasy', 'Romance', 'Mystery', 'Classics', 'Young Adult', 'Historical Fiction', 'Contemporary', 'Audiobook', 'Thriller', 'Historical', 'Science Fiction', 'Crime', 'Mystery Thriller', 'Adventure', 'Nonfiction', 'Adult', 'Literature', 'Childrens', 'Paranormal']

# %%
# Create a new DataFrame with only the rows that contain one of the selected genres
df_filtered = df[df['genres'].apply(lambda lst: any(genre in lst for genre in top_20_genres))]

print(df_filtered)
# Out:
#          userID  itemID  rating  \
# 0      31207039    3194     5.0
# 1      31207039    2232     5.0
# 2      31207039    1804     5.0
# 3      31207039    1403     4.0
# 4      31207039     104     3.0
# ...         ...     ...     ...
# 52766   2464998     521     2.0
# 52767   2464998    3012     5.0
# 52768   1815834    1198     3.0
# 52769   1815834    2680     3.0
# 52770   1815834    3351     4.0
#
#                                                   genres      price  \
# 0      ['Fiction', 'Historical Fiction', 'Classics', ...   8.717848
# 1      ['Nonfiction', 'Psychology', 'Philosophy', 'Hi...   8.717848
# 2      ['Philosophy', 'Classics', 'Nonfiction', 'Poli...  10.990000
# 3      ['Nonfiction', 'History', 'Science', 'Philosop...   8.717848
# 4      ['Classics', 'Fiction', 'Literature', 'Novels'...   8.717848
# ...                                                  ...        ...
# 52766  ['Horror', 'Fiction', 'Paranormal', 'Fantasy',...   8.717848
# 52767                              ['Horror', 'Fiction']   8.717848
# 52768  ['Horror', 'Werewolves', 'Fiction', 'Fantasy',...   3.990000
# 52769  ['Horror', 'Anthologies', 'Short Stories', 'Fi...   8.717848
# 52770  ['Horror', 'Short Stories', 'Anthologies', 'Fi...   9.990000
#
#                         publisher
# 0                 Riverhead Books
# 1                    Beacon Press
# 2                Penguin Classics
# 3                         Vintage
# 4           Vintage International
# ...                           ...
# 52766                      Warner
# 52767                      Signet
# 52768                     Fawcett
# 52769  Lectorum Publications Inc.
# 52770                         Ace
#
# [52268 rows x 6 columns]

# %%
dataset2 = Dataset()
dataset2.fit(users = df['userID'], 
            items = df['itemID'],
            item_features = top_20_genres)

# %%
item_features = dataset2.build_item_features((x, y) for x,y in zip(df.itemID, top_20_genres))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/fheshiki/Documents/GitHub/gymworkouts/notebooks/exploring-hybrid-recommeder.ipynb Cell 48 in <module>
# ----> <a href='vscode-notebook-cell:/Users/fheshiki/Documents/GitHub/gymworkouts/notebooks/exploring-hybrid-recommeder.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> item_features = dataset2.build_item_features((x, y) for x,y in zip(df.itemID, top_20_genres))
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/lightfm/data.py:418, in Dataset.build_item_features(self, data, normalize)
#     388 """
#     389 Build a item features matrix out of an iterable of the form
#     390 (item id, [list of feature names]) or (item id, {feature name: feature weight}).
#    (...)
#     407     Matrix of item features.
#     408 """
#     410 builder = _FeatureBuilder(
#     411     self._item_id_mapping,
#     412     self._item_feature_mapping,
#    (...)
#     415     "item",
#     416 )
# --> 418 return builder.build(data)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/lightfm/data.py:119, in _FeatureBuilder.build(self, data)
#     116         features.append(idx, self._feature_mapping[_id], 1.0)
#     118 for datum in data:
# --> 119     for (entity_idx, feature_idx, weight) in self._process_features(datum):
#     120         features.append(entity_idx, feature_idx, weight)
#     122 features = features.tocoo().tocsr()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/lightfm/data.py:101, in _FeatureBuilder._process_features(self, datum)
#      99 for (feature, weight) in self._iter_features(features):
#     100     if feature not in self._feature_mapping:
# --> 101         raise ValueError(
#     102             "Feature {} not in feature mapping. "
#     103             "Call fit first.".format(feature)
#     104         )
#     106     feature_idx = self._feature_mapping[feature]
#     108     yield (idx, feature_idx, weight)
#
# ValueError: Feature F not in feature mapping. Call fit first.
